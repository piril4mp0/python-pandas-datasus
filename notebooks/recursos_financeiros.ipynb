# %% [markdown]
# # Recursos Financeiros
#
# Este notebook analisa:
#
# - Total de valores aprovados pelo SUS para Santa Rosa x valores produzidos.
# - Diferença entre produzidos e aprovados.
# - Evolução do gasto médio por procedimento.
