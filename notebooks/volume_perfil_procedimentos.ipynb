# %% [markdown]
# # Volume e Perfil dos Procedimentos
#
# Este notebook analisa:
#
# - Quantos procedimentos ambulatoriais foram realizados em Santa Rosa no último mês, trimestre e ano.
# - Distribuição por especialidade/procedimento (consultas básicas, exames de imagem, oncologia, psiquiatria, etc).
# - Evolução temporal: picos e quedas na demanda.
