# %% [markdown]
# # Limpeza e Preparação dos Dados
#
# Este notebook aplica estratégias para melhorar a qualidade dos dados:
#
# - Tratar valores nulos (apagar linhas ou preencher com "Não informado").
# - Identificar e corrigir inconsistências nos dados.
# - Remover registros duplicados.
