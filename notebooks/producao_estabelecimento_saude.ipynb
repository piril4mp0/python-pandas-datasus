# %% [markdown]
# # Produção por Estabelecimento de Saúde
#
# Este notebook analisa:
#
# - Ranking de produção dos estabelecimentos (Hospital Vida & Saúde, UBS, clínicas conveniadas).
# - Comparar volume de procedimentos aprovados x produzidos.
# - Avaliar a taxa de procedimentos produzidos.
